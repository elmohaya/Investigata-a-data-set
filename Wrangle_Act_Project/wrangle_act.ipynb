# %% [markdown]
# # Project: Data Wrangling
#
# ## Table of Contents
# <ul>
# <li><a href="#intro">Introduction</a></li>
# <li><a href="#wrangling">Gathering</a></li>
# <li><a href="#eda">Assessing</a></li>
# <li><a href="#conclusions">Cleaning</a></li>
# </ul>

# %% [markdown]
# <a id='intro'></a>
# ## Introduction
#
# > This report aims to apply the process of data wrangling. It starts by gathering data from different resources either programmatically or manually. Then, the assessing step comes where the data sets are investigated to detect quality and tidiness issues. The third step is related to the cleaning process which aims to remove quality issues first and then tidiness problems.

# %% [markdown]
# ## Gathering

# %%
import pandas as pd 
import numpy as np
import requests
import os
import json
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
import tweepy
from tweepy import OAuthHandler
from timeit import default_timer as timer

# %%
# read twitter-archive file manually downloaded
tweet_archive = pd.read_csv('twitter-archive-enhanced.csv')
tweet_archive.head(40)
# Out:
#               tweet_id  in_reply_to_status_id  in_reply_to_user_id  \
# 0   892420643555336193                    NaN                  NaN
# 1   892177421306343426                    NaN                  NaN
# 2   891815181378084864                    NaN                  NaN
# 3   891689557279858688                    NaN                  NaN
# 4   891327558926688256                    NaN                  NaN
# 5   891087950875897856                    NaN                  NaN
# 6   890971913173991426                    NaN                  NaN
# 7   890729181411237888                    NaN                  NaN
# 8   890609185150312448                    NaN                  NaN
# 9   890240255349198849                    NaN                  NaN
# 10  890006608113172480                    NaN                  NaN
# 11  889880896479866881                    NaN                  NaN
# 12  889665388333682689                    NaN                  NaN
# ...

# %%
# download image-predictions file programmatically
url = 'https://d17h27t6h515a5.cloudfront.net/topher/2017/August/599fd2ad_image-predictions/image-predictions.tsv'
response = requests.get(url)

# write the content into file
with open (url.split('/')[-1], mode = 'wb') as file:
    file.write(response.content)

# %%
#read image_predictions as pandas dataframe
image_predictions = pd.read_csv('image-predictions.tsv', sep='\t')
image_predictions.head()
# Out:
#              tweet_id                                          jpg_url  \
# 0  666020888022790149  https://pbs.twimg.com/media/CT4udn0WwAA0aMy.jpg
# 1  666029285002620928  https://pbs.twimg.com/media/CT42GRgUYAA5iDo.jpg
# 2  666033412701032449  https://pbs.twimg.com/media/CT4521TWwAEvMyu.jpg
# 3  666044226329800704  https://pbs.twimg.com/media/CT5Dr8HUEAA-lEu.jpg
# 4  666049248165822465  https://pbs.twimg.com/media/CT5IQmsXIAAKY4A.jpg
#
#    img_num                      p1   p1_conf  p1_dog                  p2  \
# 0        1  Welsh_springer_spaniel  0.465074    True              collie
# 1        1                 redbone  0.506826    True  miniature_pinscher
# 2        1         German_shepherd  0.596461    True            malinois
# 3        1     Rhodesian_ridgeback  0.408143    True             redbone
# 4        1      miniature_pinscher  0.560311    True          Rottweiler
#
#     p2_conf  p2_dog                   p3   p3_conf  p3_dog
# ...

# %%
# twitter access
consumer_key = 'HIDDEN'
consumer_secret = 'HIDDEN'
access_token = 'HIDDEN'
access_secret = 'HIDDEN'

auth = OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_secret)

api = tweepy.API(auth, wait_on_rate_limit=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-70f4598702bd> in <module>
#       5 access_secret = 'HIDDEN'
#       6
# ----> 7 auth = OAuthHandler(consumer_key, consumer_secret)
#       8 auth.set_access_token(access_token, access_secret)
#       9
#
# NameError: name 'OAuthHandler' is not defined

# %%
# gather tweets in a txt file
tweet_ids = tweet_archive.tweet_id.values
len(tweet_ids)

# Query Twitter's API for JSON data for each tweet ID in the Twitter archive
count = 0
fails_dict = {}
start = timer()
# Save each tweet's returned JSON as a new line in a .txt file
with open('tweet_json.txt', 'w') as outfile:
    # This loop will likely take 20-30 minutes to run because of Twitter's rate limit
    for tweet_id in tweet_ids:
        count += 1
        print(str(count) + ": " + str(tweet_id))
        try:
            tweet = api.get_status(tweet_id, tweet_mode='extended')
            print("Success")
            json.dump(tweet._json, outfile)
            outfile.write('\n')
        except tweepy.TweepError as e:
            print("Fail")
            fails_dict[tweet_id] = e
            pass
end = timer()
print(end - start)
print(fails_dict)

# %%
list_1 = [] # empty list

# reading tweet json
with open('tweet-json.txt', encoding='utf-8')  as json_f:
    for line in json_f:
        json_expr = "{"+line.partition("{")[2]
        dictioneries = json.loads(json_expr)
        # extracting data
        id_ = dictioneries['id']
        retweet_count = dictioneries['retweet_count']
        favorite_count = dictioneries['favorite_count']    
        # append data to list   
        list_1.append({'tweet_id' : int(id_),
                        'retweet_count' : int(retweet_count),
                        'favorite_count' : int(favorite_count)})
    
    
# convert list to DataFrame  
twitter_json = pd.DataFrame(list_1, columns = ['tweet_id', 'retweet_count', 'favorite_count'])

# %%
# final DataFrame
twitter_json.head()
# Out:
#              tweet_id  retweet_count  favorite_count
# 0  892420643555336193           8853           39467
# 1  892177421306343426           6514           33819
# 2  891815181378084864           4328           25461
# 3  891689557279858688           8964           42908
# 4  891327558926688256           9774           41048

# %% [markdown]
# # Assessing

# %% [markdown]
# ## First dataframe, tweet_archive assessing:

# %%
tweet_archive.head()
# Out:
#              tweet_id  in_reply_to_status_id  in_reply_to_user_id  \
# 0  892420643555336193                    NaN                  NaN
# 1  892177421306343426                    NaN                  NaN
# 2  891815181378084864                    NaN                  NaN
# 3  891689557279858688                    NaN                  NaN
# 4  891327558926688256                    NaN                  NaN
#
#                    timestamp  \
# 0  2017-08-01 16:23:56 +0000
# 1  2017-08-01 00:17:27 +0000
# 2  2017-07-31 00:18:03 +0000
# 3  2017-07-30 15:58:51 +0000
# 4  2017-07-29 16:00:24 +0000
#
#                                               source  \
# 0  <a href="http://twitter.com/download/iphone" r...
# 1  <a href="http://twitter.com/download/iphone" r...
# 2  <a href="http://twitter.com/download/iphone" r...
# 3  <a href="http://twitter.com/download/iphone" r...
# 4  <a href="http://twitter.com/download/iphone" r...
#
# ...

# %%
tweet_archive.sample(10)
# Out:
#                 tweet_id  in_reply_to_status_id  in_reply_to_user_id  \
# 1286  708400866336894977                    NaN                  NaN
# 894   759197388317847553                    NaN                  NaN
# 1427  697630435728322560                    NaN                  NaN
# 542   806219024703037440                    NaN                  NaN
# 2044  671533943490011136                    NaN                  NaN
# 682   788552643979468800                    NaN                  NaN
# 1761  678675843183484930                    NaN                  NaN
# 1121  730924654643314689                    NaN                  NaN
# 460   817777686764523521                    NaN                  NaN
# 1544  689517482558820352                    NaN                  NaN
#
#                       timestamp  \
# 1286  2016-03-11 21:15:02 +0000
# 894   2016-07-30 01:22:17 +0000
# 1427  2016-02-11 03:57:11 +0000
# 542   2016-12-06 19:29:28 +0000
# 2044  2015-12-01 03:39:03 +0000
# ...

# %%
tweet_archive['rating_numerator'].value_counts()
# Out:
# 12      558
# 11      464
# 10      461
# 13      351
# 9       158
# 8       102
# 7        55
# 14       54
# 5        37
# 6        32
# 3        19
# 4        17
# 1         9
# 2         9
# 420       2
# 0         2
# 15        2
# 75        2
# 80        1
# 20        1
# 24        1
# 26        1
# 44        1
# 50        1
# 60        1
# 165       1
# 84        1
# 88        1
# 144       1
# 182       1
# 143       1
# 666       1
# 960       1
# 1776      1
# 17        1
# 27        1
# 45        1
# 99        1
# 121       1
# 204       1
# Name: rating_numerator, dtype: int64

# %%
tweet_archive[tweet_archive['rating_numerator']== 1776].head() # very high rating, is it error?
# Out:
#                tweet_id  in_reply_to_status_id  in_reply_to_user_id  \
# 979  749981277374128128                    NaN                  NaN
#
#                      timestamp  \
# 979  2016-07-04 15:00:45 +0000
#
#                                                 source  \
# 979  <a href="https://about.twitter.com/products/tw...
#
#                                                   text  retweeted_status_id  \
# 979  This is Atticus. He's quite simply America af....                  NaN
#
#      retweeted_status_user_id retweeted_status_timestamp  \
# 979                       NaN                        NaN
#
#                                          expanded_urls  rating_numerator  \
# 979  https://twitter.com/dog_rates/status/749981277...              1776
#
#      rating_denominator     name doggo floofer pupper puppo
# 979                  10  Atticus  None    None   None  None

# %%
tweet_archive['name'].value_counts()
# Out:
# None       745
# a           55
# Charlie     12
# Cooper      11
# Oliver      11
# Lucy        11
# Lola        10
# Penny       10
# Tucker      10
# Bo           9
# Winston      9
# the          8
# Sadie        8
# Toby         7
# Bailey       7
# Daisy        7
# Buddy        7
# an           7
# Koda         6
# Dave         6
# Milo         6
# Oscar        6
# Stanley      6
# Bella        6
# Scout        6
# Jax          6
# Rusty        6
# Leo          6
# Jack         6
# Phil         5
#           ...
# Geoff        1
# Eugene       1
# Carper       1
# Nugget       1
# Gòrdón       1
# Schnozz      1
# Remus        1
# Zooey        1
# Grey         1
# Willy        1
# Striker      1
# Dante        1
# Diogi        1
# Strudel      1
# Rolf         1
# Marvin       1
# Timber       1
# Kulet        1
# Ulysses      1
# Lambeau      1
# Lolo         1
# Lupe         1
# Kaia         1
# Bobby        1
# Eazy         1
# Todo         1
# Dudley       1
# ...

# %%
tweet_archive[tweet_archive['name']=='a'].head()
# Out:
#                 tweet_id  in_reply_to_status_id  in_reply_to_user_id  \
# 56    881536004380872706                    NaN                  NaN
# 649   792913359805018113                    NaN                  NaN
# 801   772581559778025472                    NaN                  NaN
# 1002  747885874273214464                    NaN                  NaN
# 1004  747816857231626240                    NaN                  NaN
#
#                       timestamp  \
# 56    2017-07-02 15:32:16 +0000
# 649   2016-10-31 02:17:31 +0000
# 801   2016-09-04 23:46:12 +0000
# 1002  2016-06-28 20:14:22 +0000
# 1004  2016-06-28 15:40:07 +0000
#
#                                                  source  \
# 56    <a href="http://twitter.com/download/iphone" r...
# 649   <a href="http://twitter.com/download/iphone" r...
# 801   <a href="http://twitter.com/download/iphone" r...
# 1002  <a href="http://twitter.com/download/iphone" r...
# 1004  <a href="http://twitter.com/download/iphone" r...
#
# ...

# %%
tweet_archive.shape # rows, columns
# Out:
# (2356, 17)

# %%
# unique values in each column
tweet_archive.nunique()
# Out:
# tweet_id                      2356
# in_reply_to_status_id           77
# in_reply_to_user_id             31
# timestamp                     2356
# source                           4
# text                          2356
# retweeted_status_id            181
# retweeted_status_user_id        25
# retweeted_status_timestamp     181
# expanded_urls                 2218
# rating_numerator                40
# rating_denominator              18
# name                           957
# doggo                            2
# floofer                          2
# pupper                           2
# puppo                            2
# dtype: int64

# %%
# data types and null values
tweet_archive.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2356 entries, 0 to 2355
# Data columns (total 17 columns):
# tweet_id                      2356 non-null int64
# in_reply_to_status_id         78 non-null float64
# in_reply_to_user_id           78 non-null float64
# timestamp                     2356 non-null object
# source                        2356 non-null object
# text                          2356 non-null object
# retweeted_status_id           181 non-null float64
# retweeted_status_user_id      181 non-null float64
# retweeted_status_timestamp    181 non-null object
# expanded_urls                 2297 non-null object
# rating_numerator              2356 non-null int64
# rating_denominator            2356 non-null int64
# name                          2356 non-null object
# doggo                         2356 non-null object
# floofer                       2356 non-null object
# pupper                        2356 non-null object
# ...

# %%
tweet_archive.describe() # summary statistics
# Out:
#            tweet_id  in_reply_to_status_id  in_reply_to_user_id  \
# count  2.356000e+03           7.800000e+01         7.800000e+01
# mean   7.427716e+17           7.455079e+17         2.014171e+16
# std    6.856705e+16           7.582492e+16         1.252797e+17
# min    6.660209e+17           6.658147e+17         1.185634e+07
# 25%    6.783989e+17           6.757419e+17         3.086374e+08
# 50%    7.196279e+17           7.038708e+17         4.196984e+09
# 75%    7.993373e+17           8.257804e+17         4.196984e+09
# max    8.924206e+17           8.862664e+17         8.405479e+17
#
#        retweeted_status_id  retweeted_status_user_id  rating_numerator  \
# count         1.810000e+02              1.810000e+02       2356.000000
# mean          7.720400e+17              1.241698e+16         13.126486
# std           6.236928e+16              9.599254e+16         45.876648
# min           6.661041e+17              7.832140e+05          0.000000
# ...

# %%
tweet_archive.hist(figsize=(10,8))  # histograms
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000002964CB05E10>,
# ...
#       dtype=object)

# %%
sum(tweet_archive.duplicated()) #is there any duplicated values?
# Out:
# 0

# %%
tweet_archive.isnull()
# Out:
#       tweet_id  in_reply_to_status_id  in_reply_to_user_id  timestamp  source  \
# 0        False                   True                 True      False   False
# 1        False                   True                 True      False   False
# 2        False                   True                 True      False   False
# 3        False                   True                 True      False   False
# 4        False                   True                 True      False   False
# 5        False                   True                 True      False   False
# 6        False                   True                 True      False   False
# 7        False                   True                 True      False   False
# 8        False                   True                 True      False   False
# 9        False                   True                 True      False   False
# 10       False                   True                 True      False   False
# ...

# %% [markdown]
# ## Second Dataframe, image_predictions assessing:

# %%
image_predictions.head()
# Out:
#              tweet_id                                          jpg_url  \
# 0  666020888022790149  https://pbs.twimg.com/media/CT4udn0WwAA0aMy.jpg
# 1  666029285002620928  https://pbs.twimg.com/media/CT42GRgUYAA5iDo.jpg
# 2  666033412701032449  https://pbs.twimg.com/media/CT4521TWwAEvMyu.jpg
# 3  666044226329800704  https://pbs.twimg.com/media/CT5Dr8HUEAA-lEu.jpg
# 4  666049248165822465  https://pbs.twimg.com/media/CT5IQmsXIAAKY4A.jpg
#
#    img_num                      p1   p1_conf  p1_dog                  p2  \
# 0        1  Welsh_springer_spaniel  0.465074    True              collie
# 1        1                 redbone  0.506826    True  miniature_pinscher
# 2        1         German_shepherd  0.596461    True            malinois
# 3        1     Rhodesian_ridgeback  0.408143    True             redbone
# 4        1      miniature_pinscher  0.560311    True          Rottweiler
#
#     p2_conf  p2_dog                   p3   p3_conf  p3_dog
# ...

# %%
image_predictions.sample(5)
# Out:
#                 tweet_id                                          jpg_url  \
# 1647  808733504066486276  https://pbs.twimg.com/media/Czky0v9VIAEXRkd.jpg
# 840   694669722378485760  https://pbs.twimg.com/media/CaP2bS8WYAAsMdx.jpg
# 1526  788765914992902144  https://pbs.twimg.com/media/CvJCabcWgAIoUxW.jpg
# 786   690360449368465409  https://pbs.twimg.com/media/CZSnKw8WwAAAN7q.jpg
# 1062  715220193576927233  https://pbs.twimg.com/media/Cez49UqWsAIRQXc.jpg
#
#       img_num              p1   p1_conf  p1_dog                 p2   p2_conf  \
# 1647        1       seat_belt  0.779137   False         toy_poodle  0.036927
# 840         2          beaver  0.457094   False           mongoose  0.228298
# 1526        1  cocker_spaniel  0.500509    True   golden_retriever  0.272734
# 786         1             pug  0.686933    True     French_bulldog  0.076359
# 1062        1       Chihuahua  0.584026    True  Italian_greyhound  0.377077
#
#       p2_dog                 p3   p3_conf  p3_dog
# ...

# %%
image_predictions.shape #rows, columns
# Out:
# (2075, 12)

# %%
image_predictions.info() # data types and nulls
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2075 entries, 0 to 2074
# Data columns (total 12 columns):
# tweet_id    2075 non-null int64
# jpg_url     2075 non-null object
# img_num     2075 non-null int64
# p1          2075 non-null object
# p1_conf     2075 non-null float64
# p1_dog      2075 non-null bool
# p2          2075 non-null object
# p2_conf     2075 non-null float64
# p2_dog      2075 non-null bool
# p3          2075 non-null object
# p3_conf     2075 non-null float64
# p3_dog      2075 non-null bool
# dtypes: bool(3), float64(3), int64(2), object(4)
# memory usage: 152.1+ KB

# %%
image_predictions.describe() #statistics
# Out:
#            tweet_id      img_num      p1_conf       p2_conf       p3_conf
# count  2.075000e+03  2075.000000  2075.000000  2.075000e+03  2.075000e+03
# mean   7.384514e+17     1.203855     0.594548  1.345886e-01  6.032417e-02
# std    6.785203e+16     0.561875     0.271174  1.006657e-01  5.090593e-02
# min    6.660209e+17     1.000000     0.044333  1.011300e-08  1.740170e-10
# 25%    6.764835e+17     1.000000     0.364412  5.388625e-02  1.622240e-02
# 50%    7.119988e+17     1.000000     0.588230  1.181810e-01  4.944380e-02
# 75%    7.932034e+17     1.000000     0.843855  1.955655e-01  9.180755e-02
# max    8.924206e+17     4.000000     1.000000  4.880140e-01  2.734190e-01

# %%
image_predictions.nunique()
# Out:
# tweet_id    2075
# jpg_url     2009
# img_num        4
# p1           378
# p1_conf     2006
# p1_dog         2
# p2           405
# p2_conf     2004
# p2_dog         2
# p3           408
# p3_conf     2006
# p3_dog         2
# dtype: int64

# %%
sum(image_predictions.duplicated()) #how many duplicated rows?
# Out:
# 0

# %% [markdown]
# ## Third Dataframe, twitter_json assessing:

# %%
twitter_json.head()
# Out:
#              tweet_id  retweet_count  favorite_count
# 0  892420643555336193           8853           39467
# 1  892177421306343426           6514           33819
# 2  891815181378084864           4328           25461
# 3  891689557279858688           8964           42908
# 4  891327558926688256           9774           41048

# %%
twitter_json.info() #data types and null values
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2354 entries, 0 to 2353
# Data columns (total 3 columns):
# tweet_id          2354 non-null int64
# retweet_count     2354 non-null int64
# favorite_count    2354 non-null int64
# dtypes: int64(3)
# memory usage: 55.2 KB

# %%
twitter_json.describe() #summary statistics
# Out:
#            tweet_id  retweet_count  favorite_count
# count  2.354000e+03    2354.000000     2354.000000
# mean   7.426978e+17    3164.797366     8080.968564
# std    6.852812e+16    5284.770364    11814.771334
# min    6.660209e+17       0.000000        0.000000
# 25%    6.783975e+17     624.500000     1415.000000
# 50%    7.194596e+17    1473.500000     3603.500000
# 75%    7.993058e+17    3652.000000    10122.250000
# max    8.924206e+17   79515.000000   132810.000000

# %%
twitter_json.shape #rows, columns
# Out:
# (2354, 3)

# %%
sum(twitter_json.duplicated())
# Out:
# 0

# %%
twitter_json.hist(figsize=(10,8)) #show histograms for each variable (column)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000002964CB01CC0>,
# ...
#       dtype=object)

# %% [markdown]
# ### Quality
#
# > 1- In tweet_archive, some names are written as 'a'.
#
# > 2- In tweet_archive, five columns mostly have NaN values.
#
# > 3- In tweet_archive, The last four columns variables should be boolean type; either 0 or 1.
#
# > 4- In twitter_archive, some rating denominators exceed 10.
#
# > 5- In image_predictions, all predictions columns (p1, p2, p3) should start with capital letter.
#
# > 6- In image_predictions, jpg_url column is useless for the analysis.
#
# > 7- In image_predictions, p1_conf that is less than 0.5 should not be considered for the analysis.
#
# > 8- In image_predictions, The first predictions will be used and the other two will be dropped.

# %% [markdown]
# ### Tidiness
#
# > 1- In tweet_archive the last four columns should be one column since they represent one variable.
#
# > 2- All three tables should be merged on the tweet_id column.

# %% [markdown]
# # Cleaning

# %%
# copy files for safety

tweet_archive_clean = tweet_archive.copy()
image_predictions_clean = image_predictions.copy()
twitter_json_clean = twitter_json.copy()

# %% [markdown]
# ## Quality

# %% [markdown]
# ### define
#
# > Change names in tweet_archive file that are 'a' to None
#
# ### code

# %%
tweet_archive_clean[tweet_archive_clean['name']=='a']= 'None'

# %% [markdown]
# ### Test

# %%
tweet_archive_clean[tweet_archive_clean['name']=='a'].head()
# Out:
# Empty DataFrame
# Columns: [tweet_id, in_reply_to_status_id, in_reply_to_user_id, timestamp, source, text, retweeted_status_id, retweeted_status_user_id, retweeted_status_timestamp, expanded_urls, rating_numerator, rating_denominator, name, doggo, floofer, pupper, puppo]
# Index: []

# %% [markdown]
# ### define
#
# > Drop columns in tweet_archive file that are useless or mostly empty
#
# ### code

# %%
# dropping columns with mostly NaN values
tweet_archive_clean.drop(['in_reply_to_status_id','in_reply_to_user_id','retweeted_status_id','retweeted_status_user_id','retweeted_status_timestamp'], axis=1, inplace = True)

# %% [markdown]
# ### Test

# %%
tweet_archive_clean.head()
# Out:
#              tweet_id                  timestamp  \
# 0  892420643555336193  2017-08-01 16:23:56 +0000
# 1  892177421306343426  2017-08-01 00:17:27 +0000
# 2  891815181378084864  2017-07-31 00:18:03 +0000
# 3  891689557279858688  2017-07-30 15:58:51 +0000
# 4  891327558926688256  2017-07-29 16:00:24 +0000
#
#                                               source  \
# 0  <a href="http://twitter.com/download/iphone" r...
# 1  <a href="http://twitter.com/download/iphone" r...
# 2  <a href="http://twitter.com/download/iphone" r...
# 3  <a href="http://twitter.com/download/iphone" r...
# 4  <a href="http://twitter.com/download/iphone" r...
#
#                                                 text  \
# 0  This is Phineas. He's a mystical boy. Only eve...
# 1  This is Tilly. She's just checking pup on you....
# 2  This is Archie. He is a rare Norwegian Pouncin...
# 3  This is Darla. She commenced a snooze mid meal...
# 4  This is Franklin. He would like you to stop ca...
#
# ...

# %% [markdown]
# ### define
#
# > Make the last four columns in tweet_archive dataset as boolean variable
#
# ### code

# %%
d = {'doggo': 1, 'None': 0} # A temproralily dictionary for the doggo column

tweet_archive_clean['doggo'] = tweet_archive_clean['doggo'].map(d)

d1 = {'floofer': 1, 'None': 0} # A temproralily dictionary for the floofer column
tweet_archive_clean['floofer'] = tweet_archive_clean['floofer'].map(d1)

d2 = {'pupper': 1, 'None': 0}  # A temproralily dictionary for the pupper column
tweet_archive_clean['pupper'] = tweet_archive_clean['pupper'].map(d2)

d3 = {'puppo': 1, 'None': 0}  # A temproralily dictionary for the puppo column
tweet_archive_clean['puppo'] = tweet_archive_clean['puppo'].map(d3)

# %% [markdown]
# ### Test

# %%
tweet_archive_clean.head(40)
# Out:
#               tweet_id                  timestamp  \
# 0   892420643555336193  2017-08-01 16:23:56 +0000
# 1   892177421306343426  2017-08-01 00:17:27 +0000
# 2   891815181378084864  2017-07-31 00:18:03 +0000
# 3   891689557279858688  2017-07-30 15:58:51 +0000
# 4   891327558926688256  2017-07-29 16:00:24 +0000
# 5   891087950875897856  2017-07-29 00:08:17 +0000
# 6   890971913173991426  2017-07-28 16:27:12 +0000
# 7   890729181411237888  2017-07-28 00:22:40 +0000
# 8   890609185150312448  2017-07-27 16:25:51 +0000
# 9   890240255349198849  2017-07-26 15:59:51 +0000
# 10  890006608113172480  2017-07-26 00:31:25 +0000
# 11  889880896479866881  2017-07-25 16:11:53 +0000
# 12  889665388333682689  2017-07-25 01:55:32 +0000
# 13  889638837579907072  2017-07-25 00:10:02 +0000
# 14  889531135344209921  2017-07-24 17:02:04 +0000
# 15  889278841981685760  2017-07-24 00:19:32 +0000
# 16  888917238123831296  2017-07-23 00:22:39 +0000
# 17  888804989199671297  2017-07-22 16:56:37 +0000
# ...

# %% [markdown]
# ### define
#
# > Change denominator values that are greater than 10 in tweet_archive into 10.
#
# ### code

# %%
tweet_archive_clean['rating_denominator'] = 10

# %% [markdown]
# ### Test

# %%
tweet_archive_clean['rating_denominator'].value_counts()
# Out:
# 10    2356
# Name: rating_denominator, dtype: int64

# %% [markdown]
# ### define
#
# > Make p1, p2, p3 in image predictions data set start with capital letters
#
# ### code

# %%
image_predictions_clean['p1'] = image_predictions_clean.p1.str.title() # make the first letter capital
image_predictions_clean['p2'] = image_predictions_clean.p2.str.title()
image_predictions_clean['p3'] = image_predictions_clean.p3.str.title()

# %% [markdown]
# ### Test

# %%
image_predictions_clean.head()
# Out:
#              tweet_id                                          jpg_url  \
# 0  666020888022790149  https://pbs.twimg.com/media/CT4udn0WwAA0aMy.jpg
# 1  666029285002620928  https://pbs.twimg.com/media/CT42GRgUYAA5iDo.jpg
# 2  666033412701032449  https://pbs.twimg.com/media/CT4521TWwAEvMyu.jpg
# 3  666044226329800704  https://pbs.twimg.com/media/CT5Dr8HUEAA-lEu.jpg
# 4  666049248165822465  https://pbs.twimg.com/media/CT5IQmsXIAAKY4A.jpg
#
#    img_num                      p1   p1_conf  p1_dog                  p2  \
# 0        1  Welsh_Springer_Spaniel  0.465074    True              Collie
# 1        1                 Redbone  0.506826    True  Miniature_Pinscher
# 2        1         German_Shepherd  0.596461    True            Malinois
# 3        1     Rhodesian_Ridgeback  0.408143    True             Redbone
# 4        1      Miniature_Pinscher  0.560311    True          Rottweiler
#
#     p2_conf  p2_dog                   p3   p3_conf  p3_dog
# ...

# %% [markdown]
# ### define
#
# > Remove jpg_url column from image_predictions data set
#
# ### code

# %%
image_predictions_clean.drop(['jpg_url'], axis=1, inplace=True) #drop the third column

# %% [markdown]
# ### Test

# %%
image_predictions_clean.head(40)
# Out:
#               tweet_id  img_num                           p1   p1_conf  \
# 0   666020888022790149        1       Welsh_Springer_Spaniel  0.465074
# 1   666029285002620928        1                      Redbone  0.506826
# 2   666033412701032449        1              German_Shepherd  0.596461
# 3   666044226329800704        1          Rhodesian_Ridgeback  0.408143
# 4   666049248165822465        1           Miniature_Pinscher  0.560311
# 5   666050758794694657        1         Bernese_Mountain_Dog  0.651137
# 6   666051853826850816        1                   Box_Turtle  0.933012
# 7   666055525042405380        1                         Chow  0.692517
# 8   666057090499244032        1                Shopping_Cart  0.962465
# 9   666058600524156928        1             Miniature_Poodle  0.201493
# 10  666063827256086533        1             Golden_Retriever  0.775930
# 11  666071193221509120        1                Gordon_Setter  0.503672
# ...

# %% [markdown]
# ### define
#
# > Drop rows with p1_conf less than 0.5
#
# ### code

# %%
image_predictions_clean = image_predictions_clean.query('p1_conf >= 0.5') #consider only above 0.5 p1_conf

# %% [markdown]
# ### Test

# %%
image_predictions_clean['p1_conf']
# Out:
# 1       0.506826
# 2       0.596461
# 4       0.560311
# 5       0.651137
# 6       0.933012
# 7       0.692517
# 8       0.962465
# 10      0.775930
# 11      0.503672
# 15      0.582330
# 17      0.965932
# 20      0.857531
# 21      0.914671
# 23      0.858744
# 25      0.996496
# 27      0.978108
# 28      0.529139
# 31      0.906777
# 33      0.505184
# 35      0.671853
# 40      0.975401
# 41      0.887707
# 42      0.546933
# 44      0.618316
# 45      0.999888
# 51      0.589446
# 52      0.507637
# 53      0.987230
# 54      0.765266
# 55      0.825678
#           ...
# 2032    0.987997
# 2033    0.943082
# 2034    0.610946
# 2035    0.707046
# 2036    0.993225
# 2037    0.546406
# 2038    0.822103
# 2040    0.812482
# 2041    0.908703
# 2043    0.972494
# 2044    0.943575
# 2045    0.999201
# 2046    0.738995
# 2048    0.793469
# 2049    0.733942
# 2051    0.809197
# 2053    0.821664
# 2054    0.995026
# 2055    0.809197
# 2056    0.700377
# 2058    0.714719
# ...

# %% [markdown]
# ### define
#
# > Consider only p1 and p1_conf in image_predictions data set
#
# ### code

# %%
image_predictions_clean.drop(['p2', 'p2_conf', 'p3', 'p3_conf', 'p2_dog', 'p3_dog'], axis=1, inplace=True) # droppint the last six columns

# %% [markdown]
# ### Test

# %%
image_predictions_clean.head()
# Out:
#              tweet_id  img_num                    p1   p1_conf  p1_dog
# 1  666029285002620928        1               Redbone  0.506826    True
# 2  666033412701032449        1       German_Shepherd  0.596461    True
# 4  666049248165822465        1    Miniature_Pinscher  0.560311    True
# 5  666050758794694657        1  Bernese_Mountain_Dog  0.651137    True
# 6  666051853826850816        1            Box_Turtle  0.933012   False

# %% [markdown]
# ## Tidiness

# %% [markdown]
# ### define:
#
# > Remove the dummy variables in the last four columns and make on column
#
# ### code:

# %%
tweet_archive_clean.head()
# Out:
#              tweet_id                  timestamp  \
# 0  892420643555336193  2017-08-01 16:23:56 +0000
# 1  892177421306343426  2017-08-01 00:17:27 +0000
# 2  891815181378084864  2017-07-31 00:18:03 +0000
# 3  891689557279858688  2017-07-30 15:58:51 +0000
# 4  891327558926688256  2017-07-29 16:00:24 +0000
#
#                                               source  \
# 0  <a href="http://twitter.com/download/iphone" r...
# 1  <a href="http://twitter.com/download/iphone" r...
# 2  <a href="http://twitter.com/download/iphone" r...
# 3  <a href="http://twitter.com/download/iphone" r...
# 4  <a href="http://twitter.com/download/iphone" r...
#
#                                                 text  \
# 0  This is Phineas. He's a mystical boy. Only eve...
# 1  This is Tilly. She's just checking pup on you....
# 2  This is Archie. He is a rare Norwegian Pouncin...
# 3  This is Darla. She commenced a snooze mid meal...
# 4  This is Franklin. He would like you to stop ca...
#
# ...

# %%
# Undummy the last four columns in tweet archive data set
tweet_archive_clean['type']= 'Other' #creat new column

for i in range(tweet_archive_clean.shape[0]):
    if (tweet_archive_clean['doggo'][i] == 1):
        tweet_archive_clean['type'][i]= 'doggo'
    elif (tweet_archive_clean['floofer'][i] == 1):
         tweet_archive_clean['type'][i]= 'floofer'
    elif ( tweet_archive_clean['pupper'][i]== 1):
         tweet_archive_clean['type'][i]= 'pupper'
    elif ( tweet_archive_clean['puppo'][i]== 1):
         tweet_archive_clean['type'][i]= 'puppo'
    else :
        continue
# Out:
# C:\Users\SAMSUNG\Anaconda3\lib\site-packages\ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# C:\Users\SAMSUNG\Anaconda3\lib\site-packages\ipykernel_launcher.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if sys.path[0] == '':
# C:\Users\SAMSUNG\Anaconda3\lib\site-packages\ipykernel_launcher.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   # Remove the CWD from sys.path while we load stuff.
# ...

# %% [markdown]
# ### Test:

# %%
tweet_archive_clean.head(100)
# Out:
#               tweet_id                  timestamp  \
# 0   892420643555336193  2017-08-01 16:23:56 +0000
# 1   892177421306343426  2017-08-01 00:17:27 +0000
# 2   891815181378084864  2017-07-31 00:18:03 +0000
# 3   891689557279858688  2017-07-30 15:58:51 +0000
# 4   891327558926688256  2017-07-29 16:00:24 +0000
# 5   891087950875897856  2017-07-29 00:08:17 +0000
# 6   890971913173991426  2017-07-28 16:27:12 +0000
# 7   890729181411237888  2017-07-28 00:22:40 +0000
# 8   890609185150312448  2017-07-27 16:25:51 +0000
# 9   890240255349198849  2017-07-26 15:59:51 +0000
# 10  890006608113172480  2017-07-26 00:31:25 +0000
# 11  889880896479866881  2017-07-25 16:11:53 +0000
# 12  889665388333682689  2017-07-25 01:55:32 +0000
# 13  889638837579907072  2017-07-25 00:10:02 +0000
# 14  889531135344209921  2017-07-24 17:02:04 +0000
# 15  889278841981685760  2017-07-24 00:19:32 +0000
# 16  888917238123831296  2017-07-23 00:22:39 +0000
# 17  888804989199671297  2017-07-22 16:56:37 +0000
# ...

# %% [markdown]
# ### define:
#
# > Merge all three tables together
#
# ### code:

# %%
twitter_json_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2354 entries, 0 to 2353
# Data columns (total 3 columns):
# tweet_id          2354 non-null int64
# retweet_count     2354 non-null int64
# favorite_count    2354 non-null int64
# dtypes: int64(3)
# memory usage: 55.2 KB

# %%
tweet_archive_clean.tweet_id = tweet_archive.tweet_id

temp = pd.merge(tweet_archive_clean, image_predictions_clean, on=['tweet_id'], how='left') # temp data set
maste_data_set = pd.merge(temp, twitter_json, on=['tweet_id'], how = 'left') # join all three together

# %% [markdown]
# ### Test

# %%
maste_data_set.head(150)
# Out:
#                tweet_id                  timestamp  \
# 0    892420643555336193  2017-08-01 16:23:56 +0000
# 1    892177421306343426  2017-08-01 00:17:27 +0000
# 2    891815181378084864  2017-07-31 00:18:03 +0000
# 3    891689557279858688  2017-07-30 15:58:51 +0000
# 4    891327558926688256  2017-07-29 16:00:24 +0000
# 5    891087950875897856  2017-07-29 00:08:17 +0000
# 6    890971913173991426  2017-07-28 16:27:12 +0000
# 7    890729181411237888  2017-07-28 00:22:40 +0000
# 8    890609185150312448  2017-07-27 16:25:51 +0000
# 9    890240255349198849  2017-07-26 15:59:51 +0000
# 10   890006608113172480  2017-07-26 00:31:25 +0000
# 11   889880896479866881  2017-07-25 16:11:53 +0000
# 12   889665388333682689  2017-07-25 01:55:32 +0000
# 13   889638837579907072  2017-07-25 00:10:02 +0000
# 14   889531135344209921  2017-07-24 17:02:04 +0000
# 15   889278841981685760  2017-07-24 00:19:32 +0000
# 16   888917238123831296  2017-07-23 00:22:39 +0000
# ...

# %% [markdown]
# # Cleaning The Final Version and Assessing

# %%
sum(maste_data_set['tweet_id'].duplicated()) #check for any duplicates
# Out:
# 0

# %%
maste_data_set.dropna(axis=0, how='any', thresh=None, subset=None, inplace=True) # removing missing values 
maste_data_set.head()
# Out:
#               tweet_id                  timestamp  \
# 2   891815181378084864  2017-07-31 00:18:03 +0000
# 4   891327558926688256  2017-07-29 16:00:24 +0000
# 7   890729181411237888  2017-07-28 00:22:40 +0000
# 9   890240255349198849  2017-07-26 15:59:51 +0000
# 10  890006608113172480  2017-07-26 00:31:25 +0000
#
#                                                source  \
# 2   <a href="http://twitter.com/download/iphone" r...
# 4   <a href="http://twitter.com/download/iphone" r...
# 7   <a href="http://twitter.com/download/iphone" r...
# 9   <a href="http://twitter.com/download/iphone" r...
# 10  <a href="http://twitter.com/download/iphone" r...
#
#                                                  text  \
# 2   This is Archie. He is a rare Norwegian Pouncin...
# 4   This is Franklin. He would like you to stop ca...
# 7   When you watch your owner call another dog a g...
# 9   This is Cassie. She is a college pup. Studying...
# 10  This is Koda. He is a South Australian decksha...
#
# ...

# %%
maste_data_set.reset_index(drop=True,inplace=True) #reset Index
maste_data_set.head()
# Out:
#              tweet_id                  timestamp  \
# 0  891815181378084864  2017-07-31 00:18:03 +0000
# 1  891327558926688256  2017-07-29 16:00:24 +0000
# 2  890729181411237888  2017-07-28 00:22:40 +0000
# 3  890240255349198849  2017-07-26 15:59:51 +0000
# 4  890006608113172480  2017-07-26 00:31:25 +0000
#
#                                               source  \
# 0  <a href="http://twitter.com/download/iphone" r...
# 1  <a href="http://twitter.com/download/iphone" r...
# 2  <a href="http://twitter.com/download/iphone" r...
# 3  <a href="http://twitter.com/download/iphone" r...
# 4  <a href="http://twitter.com/download/iphone" r...
#
#                                                 text  \
# 0  This is Archie. He is a rare Norwegian Pouncin...
# 1  This is Franklin. He would like you to stop ca...
# 2  When you watch your owner call another dog a g...
# 3  This is Cassie. She is a college pup. Studying...
# 4  This is Koda. He is a South Australian decksha...
#
# ...

# %%
maste_data_set.drop(['doggo','floofer','pupper','puppo'], axis=1, inplace=True) #dropm dummy variables
maste_data_set.head(150)
# Out:
#                tweet_id                  timestamp  \
# 0    891815181378084864  2017-07-31 00:18:03 +0000
# 1    891327558926688256  2017-07-29 16:00:24 +0000
# 2    890729181411237888  2017-07-28 00:22:40 +0000
# 3    890240255349198849  2017-07-26 15:59:51 +0000
# 4    890006608113172480  2017-07-26 00:31:25 +0000
# 5    889665388333682689  2017-07-25 01:55:32 +0000
# 6    889638837579907072  2017-07-25 00:10:02 +0000
# 7    889531135344209921  2017-07-24 17:02:04 +0000
# 8    889278841981685760  2017-07-24 00:19:32 +0000
# 9    888917238123831296  2017-07-23 00:22:39 +0000
# 10   888554962724278272  2017-07-22 00:23:06 +0000
# 11   888078434458587136  2017-07-20 16:49:33 +0000
# 12   887705289381826560  2017-07-19 16:06:48 +0000
# 13   887473957103951883  2017-07-19 00:47:34 +0000
# 14   887101392804085760  2017-07-18 00:07:08 +0000
# 15   886983233522544640  2017-07-17 16:17:36 +0000
# 16   886680336477933568  2017-07-16 20:14:00 +0000
# ...

# %% [markdown]
# # Saving

# %%
maste_data_set.to_csv('master_data_set.csv', index = False)

# %% [markdown]
# # Analyzing the master data set

# %% [markdown]
# > In this part of the project we have completed all wrangling steps which are gathering, assessing, and cleaning. Finally we came up with a master data set that is ready now to be analyzed. In the following analysis we will try to answer the following questions:
#
# > 1- What is the percentage of each type of dogs?
#
# > 2- What type of dogs (doggo, floofer, puppo, pupper) has the highest retweet_count averege?
#
# > 3- What type of dogs (doggo, floofer, puppo, pupper) has the highest favorite_count averege?

# %%
doggo = len(maste_data_set[maste_data_set['type']=='doggo']) # count the number of doggo
floofer = len(maste_data_set[maste_data_set['type']=='floofer']) 
puppo = len(maste_data_set[maste_data_set['type']=='puppo']) 
pupper = len(maste_data_set[maste_data_set['type']=='pupper']) 
other = maste_data_set.shape[0] - doggo - floofer- pupper - puppo

#ploting the four dogs groupes percentages 
labels = 'doggo', 'floofer', 'puppo', 'pupper', 'other'
sizes = [doggo, floofer, puppo, pupper, other]
colors = ['gold', 'yellowgreen', 'lightcoral', 'lightskyblue', 'red']
explode = (0.1, 0, 0, 0, 0)  # explode 1st slice

# Plot
plt.pie(sizes, explode=explode, labels=labels, colors=colors,
autopct='%1.1f%%', shadow=True, startangle=140)

plt.axis('equal')
plt.show()

# %%
# what type of dogs has the highest retweet_count average?

doggo_retweet_average = maste_data_set[maste_data_set['type']=='doggo']['retweet_count'].mean()
floofer_retweet_average = maste_data_set[maste_data_set['type']=='floofer']['retweet_count'].mean()
puppo_retweet_average = maste_data_set[maste_data_set['type']=='puppo']['retweet_count'].mean()
pupper_retweet_average = maste_data_set[maste_data_set['type']=='pupper']['retweet_count'].mean()

doggo_retweet_average, floofer_retweet_average, puppo_retweet_average, pupper_retweet_average
# Out:
# (7597.076923076923, 7606.0, 4975.578947368421, 2604.6356589147285)

# %% [markdown]
# **It seems that floofer dogs has the highest retweet count average**

# %%
# what type of dogs has the highest favorite_count average?

doggo_favorite_average = maste_data_set[maste_data_set['type']=='doggo']['favorite_count'].mean()
floofer_favorite_average = maste_data_set[maste_data_set['type']=='floofer']['favorite_count'].mean()
puppo_favorite_average = maste_data_set[maste_data_set['type']=='puppo']['favorite_count'].mean()
pupper_favorite_average = maste_data_set[maste_data_set['type']=='pupper']['favorite_count'].mean()

doggo_favorite_average, floofer_favorite_average, puppo_favorite_average, pupper_favorite_average
# Out:
# (17460.21153846154, 19531.0, 17050.684210526317, 7614.3488372093025)

# %% [markdown]
# **It seems that also floofer dogs has the highest favorite count average**

# %% [markdown]
# # Conclusion
#
# > The wrangling process is a step before start analyzing and answering questions
#
# > In this project we have gathered, assessed, cleaned, and analyzed the data sets and answer the following questions:
#
# > 1- What is the percentage of each type of dogs?
#
# > 2- What type of dogs (doggo, floofer, puppo, pupper) has the highest retweet_count averege?
#
# > 3- What type of dogs (doggo, floofer, puppo, pupper) has the highest favorite_count averege?
